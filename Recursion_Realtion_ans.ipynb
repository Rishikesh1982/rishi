# %% [markdown]
# **T(n)=3T(n-1)+12n**
#
# To find T(2) first we have to T(1).
#
# =>T(1)=3T(1-1)+12(1)
#
#   T(1)=3T(0)+12    -->eq( 1 )
#
#
#   We know that T(0)=5,
#
#   substitute this value in eq(1)
#
#   T(1)=3(5)+12
#
#   T(1)=15+12
#
#   __T(1)=27__
#
# =>T(2)=3T(2-1)+12(2)
#
#   T(2)=3T(1)+24        -->eq( 2 )
#
#   We know that T(1)=27,
#
#   substitute this value in eq(2)
#
#   T(2)=3(27)+24
#
#   T(2)=81+24
#
#   __T(2)=105__
#
#   **The value of T(2) is 105.**

# %% [markdown]
# **a)**
# T(n)=T(n-1)+c  -->eq( 1 )
#
# Then we substitute (n-1) in n.
#
# T(n-1)=T(n-1-1)+c
#
# T(n-1)=T(n-2)+c  -->eq( 2 )
#
# Substitute eq(2) in eq(1).
#
# T(n)=T(T(n-2)+c)+c
#
# T(n)=T(n-2)+2c   -->eq( 3 )
#
# T(n)=T(n-3)+3c   -->eq( 4 )
#
# After repeating k steps.
#
# T(n)=T(n-k)+kc   -->eq( 5 )
#
# When n-k=0 and n=k.
#
# T(n)=T(0)+nc
#
# So, the final recursion relation for T(n)=T(n-1)+c is T(n)=T0+nc. Where T0 is initial value at n=0.
#
#
# **b)**
# T(n)=2T(n/2)+n
#
# Assume T(n)=f(n).
#
# f(n)=2f(n/2)+1
#
# Divide both sides with n.
#
# f(n)/n=(2f(n/2)/n)+1
#
# Divide both sides with 2.
#
# f(n)/2n=(f(n/2)/n)+1/2
#
# f(n)/n=(f(n/2)/n/2)+1/2
#
# Consider 1/2 as a constant.
#
# We conclude that T(n)=f(n).
#
# The solution is T(n)=nlog(n)
#
# **c)**
# T(n)=2T(n/2)+c  -->eq( 1 )
#
# T(n)=2^2T(n/2^2)+2c  -->eq( 2 )
#
# T(n)=2^3T(n/2^3)+3c   -->eq( 3 )
#
# After continuousely do k times.
#
# T(n)=2^kT(n/2^k)+nc   -->eq( 4 )
#
# n/2^k=2, n=2^k+1
#
# log(n)=log(2^k+1)
#
# k+1=log2(n)
#
# 2^k+n-2
#
# 2^k=n/2
#
# n/2+n-2
#
# 3n/2-2
#
# O(n)

# %% [markdown]
# **a)**
# T(n)=2T(n-1)+1--( 1 )
#
# When we substitute n-1 in n.
#
# T(n-1)=2T(n-2)+1--( 2 )
#
# substitute eq(2) in eq(1).
#
# If we do continuesly like this in k times.
#
# we get  1,2,2^2,2^3,2^4,...,2^n
#
# This is geometric series.
#
# The formula for  geametric series is a,ar,ar^2,ar^3,ar^4,.....,ar^n=a((r^k+1)-1/
# (r-1))
#
# In our series a=1, r=2
#
# (2^k+1)-1
#
# We know n-k=0,n=k
#
# (2^n+1)-1
#
# Finally I am concluding that O(2^n)
#
# **b)**
# T(n)=2T(n/2)+cn
#
# T(n)=T(n/2)+T(n/2)+cn
#
# n-->n/2 , n/2
#
# n/2 , n/2-->n/2^2 n/2^2 , n/2^2 n/2^2
#
# After continously doing this k times it will become.
#
# n/2^k n/2^k n/2^k n/2^k.....n/2^k
#
# k.cn
#
# n/2^k=1, n=2^k, k=log(n)
#
# log(n).cn
#
# O(nlogn)
